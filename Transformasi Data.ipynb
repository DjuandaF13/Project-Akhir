# %%
import os
import glob

def rename_positive_files(directory, prefix="pos_"):
    """
    Mengganti nama file JPG dan XML yang berpasangan di direktori tertentu
    menjadi format berurutan (misal: pos_0001.jpg, pos_0001.xml).
    """
    print(f"Memulai proses penamaan ulang di direktori: {directory}")

    # Mengumpulkan semua file JPG
    # Gunakan glob untuk menemukan semua file dengan ekstensi .jpg, .jpeg, .png, .bmp
    # Pastikan untuk mencari file secara case-insensitive jika perlu (misal: *.JPG, *.jpeg)
    image_files = []
    for ext in ['*.jpg', '*.jpeg', '*.png', '*.bmp']:
        image_files.extend(glob.glob(os.path.join(directory, ext)))

    image_files.sort() # Urutkan file agar penamaan berurutan konsisten

    if not image_files:
        print("Tidak ada file gambar yang ditemukan di direktori ini.")
        return

    print(f"Ditemukan {len(image_files)} file gambar untuk diproses.")

    renamed_count = 0
    for i, old_image_path in enumerate(image_files):
        # Pisahkan nama file dan ekstensi
        base_name = os.path.splitext(os.path.basename(old_image_path))[0]
        image_extension = os.path.splitext(old_image_path)[1]

        # Path ke file XML yang diharapkan
        old_xml_path = os.path.join(directory, base_name + '.xml')

        # Buat nama baru yang berurutan
        new_base_name = f"{prefix}{i+1:04d}" # Menggunakan 4 digit padding (0001, 0002, ...)
        new_image_path = os.path.join(directory, new_base_name + image_extension)
        new_xml_path = os.path.join(directory, new_base_name + '.xml')

        # Cek apakah file XML yang sesuai ada
        if os.path.exists(old_xml_path):
            try:
                # Ganti nama file gambar
                os.rename(old_image_path, new_image_path)
                print(f"Mengganti nama: '{os.path.basename(old_image_path)}' -> '{os.path.basename(new_image_path)}'")

                # Ganti nama file XML
                os.rename(old_xml_path, new_xml_path)
                print(f"Mengganti nama: '{os.path.basename(old_xml_path)}' -> '{os.path.basename(new_xml_path)}'")
                renamed_count += 1
            except OSError as e:
                print(f"Error saat mengganti nama '{old_image_path}' atau '{old_xml_path}': {e}")
        else:
            print(f"Melewatkan '{os.path.basename(old_image_path)}': File XML yang sesuai ({os.path.basename(old_xml_path)}) tidak ditemukan.")

    print(f"\nProses penamaan ulang selesai. Total {renamed_count} pasangan file (JPG dan XML) berhasil diganti namanya.")
    if renamed_count < len(image_files):
        print("Beberapa file gambar dilewatkan karena tidak memiliki file XML yang sesuai.")

# --- Cara Penggunaan ---
if __name__ == "__main__":
    # GANTI DENGAN PATH KE FOLDER "Gambar Positif" ANDA
    positive_images_folder = r"D:\Penelitian Skripsi\Dataset\Gambar Positif"

    rename_positive_files(positive_images_folder)
# Out:
# Memulai proses penamaan ulang di direktori: D:\Penelitian Skripsi\Dataset\Gambar Positif
# Ditemukan 103 file gambar untuk diproses.
# Mengganti nama: '1000_F_223952188_K8pFfnUBNXerHrCN2uxrUwV6QF6F3NrE_jpeg.rf.28548a2515b03315ac6263e09493a09f.jpg' -> 'pos_0001.jpg'
# Mengganti nama: '1000_F_223952188_K8pFfnUBNXerHrCN2uxrUwV6QF6F3NrE_jpeg.rf.28548a2515b03315ac6263e09493a09f.xml' -> 'pos_0001.xml'
# Mengganti nama: 'cabbage-wrapped-cellophane-spoiled-vegetable-260nw-1731428260_jpeg.rf.2d39a1582be8a172ebfac8f76522a685.jpg' -> 'pos_0080.jpg'
# Mengganti nama: 'cabbage-wrapped-cellophane-spoiled-vegetable-260nw-1731428260_jpeg.rf.2d39a1582be8a172ebfac8f76522a685.xml' -> 'pos_0080.xml'
# Mengganti nama: 'cara-pengendalian-busuk-hitam-pada-kubis_jpeg.rf.38b8000fabe11d7bfdcae2d94cd308b0.jpg' -> 'pos_0081.jpg'
# Mengganti nama: 'cara-pengendalian-busuk-hitam-pada-kubis_jpeg.rf.38b8000fabe11d7bfdcae2d94cd308b0.xml' -> 'pos_0081.xml'
# Mengganti nama: 'clap-wilted-lettuce_jpeg.rf.dc75cd0d7cfeca36a066553dbd47f98a.jpg' -> 'pos_0082.jpg'
# Mengganti nama: 'clap-wilted-lettuce_jpeg.rf.dc75cd0d7cfeca36a066553dbd47f98a.xml' -> 'pos_0082.xml'
# Mengganti nama: 'close-up-spoiled-rotten-cabbage-mold-isolated-close-up-spoiled-rotten-cabbage-mold-isolated-215512244_jpeg.rf.84a12e1819881219cde187c05096c9ef.jpg' -> 'pos_0083.jpg'
# Mengganti nama: 'close-up-spoiled-rotten-cabbage-mold-isolated-close-up-spoiled-rotten-cabbage-mold-isolated-215512244_jpeg.rf.84a12e1819881219cde187c05096c9ef.xml' -> 'pos_0083.xml'
# Mengganti nama: 'closeup-spoiled-rotten-cabbage-mold-260nw-1950968338_jpeg_jpg.rf.7a4e71de78627465312fbd3b56b660d7.jpg' -> 'pos_0084.jpg'
# Mengganti nama: 'closeup-spoiled-rotten-cabbage-mold-260nw-1950968338_jpeg_jpg.rf.7a4e71de78627465312fbd3b56b660d7.xml' -> 'pos_0084.xml'
# Mengganti nama: 'closeup-spoiled-rotten-cabbage-mold-260nw-1950968338_jpeg_jpg.rf.959e5737956283f3f270e52dddf9509a.jpg' -> 'pos_0085.jpg'
# Mengganti nama: 'closeup-spoiled-rotten-cabbage-mold-260nw-1950968338_jpeg_jpg.rf.959e5737956283f3f270e52dddf9509a.xml' -> 'pos_0085.xml'
# Mengganti nama: 'com_w400_-1-_jpeg.rf.4710ae357a322626461b552056e52ae4.jpg' -> 'pos_0086.jpg'
# Mengganti nama: 'com_w400_-1-_jpeg.rf.4710ae357a322626461b552056e52ae4.xml' -> 'pos_0086.xml'
# Mengganti nama: 'daun-latensi-busuk-ditinggalkan-ladang-tercemar_jpeg.rf.4e27adc6e17f39b0e4ab1690bdc3d845.jpg' -> 'pos_0087.jpg'
# Mengganti nama: 'daun-latensi-busuk-ditinggalkan-ladang-tercemar_jpeg.rf.4e27adc6e17f39b0e4ab1690bdc3d845.xml' -> 'pos_0087.xml'
# Mengganti nama: 'daun-latensi-busuk-ditinggalkan-ladang-tercemar_jpeg.rf.c004b6d0891a0291ec09afd49f5c5681.jpg' -> 'pos_0088.jpg'
# Mengganti nama: 'daun-latensi-busuk-ditinggalkan-ladang-tercemar_jpeg.rf.c004b6d0891a0291ec09afd49f5c5681.xml' -> 'pos_0088.xml'
# Mengganti nama: 'daun-latensi-busuk-ditinggalkan-ladang-tercemar_jpeg.rf.f1a27ed74022425d1e02ede5d5c159d4.jpg' -> 'pos_0089.jpg'
# Mengganti nama: 'daun-latensi-busuk-ditinggalkan-ladang-tercemar_jpeg.rf.f1a27ed74022425d1e02ede5d5c159d4.xml' -> 'pos_0089.xml'
# Mengganti nama: 'depositphotos_70565965-stock-photo-rotten-cabbage_jpeg.rf.296d8cbc5d49170edf4ac2870e6338e5.jpg' -> 'pos_0090.jpg'
# Mengganti nama: 'depositphotos_70565965-stock-photo-rotten-cabbage_jpeg.rf.296d8cbc5d49170edf4ac2870e6338e5.xml' -> 'pos_0090.xml'
# Mengganti nama: 'depositphotos_71199497-stock-photo-spoiled-cabbage-isolated-on-white-1-_jpeg.rf.06f173216c3a1ceaea31e13a90745d3f.jpg' -> 'pos_0091.jpg'
# Mengganti nama: 'depositphotos_71199497-stock-photo-spoiled-cabbage-isolated-on-white-1-_jpeg.rf.06f173216c3a1ceaea31e13a90745d3f.xml' -> 'pos_0091.xml'
# Mengganti nama: 'depositphotos_71199497-stock-photo-spoiled-cabbage-isolated-on-white-1-_jpeg.rf.a1a81da8ed6267a159306f5b6e17e8d1.jpg' -> 'pos_0092.jpg'
# Mengganti nama: 'depositphotos_71199497-stock-photo-spoiled-cabbage-isolated-on-white-1-_jpeg.rf.a1a81da8ed6267a159306f5b6e17e8d1.xml' -> 'pos_0092.xml'
# Mengganti nama: 'group-rotten-cabbage-spolied-leaves-as-part-food-waste-loss-227315322_jpeg.rf.38f0c3016f95715ed7c777b0830ed291.jpg' -> 'pos_0093.jpg'
# Mengganti nama: 'group-rotten-cabbage-spolied-leaves-as-part-food-waste-loss-227315322_jpeg.rf.38f0c3016f95715ed7c777b0830ed291.xml' -> 'pos_0093.xml'
# Mengganti nama: 'group-rotten-cabbage-spolied-leaves-as-part-food-waste-loss-227315322_jpeg.rf.687f1ef602e52fbedf438cfa822b2c72.jpg' -> 'pos_0094.jpg'
# Mengganti nama: 'group-rotten-cabbage-spolied-leaves-as-part-food-waste-loss-227315322_jpeg.rf.687f1ef602e52fbedf438cfa822b2c72.xml' -> 'pos_0094.xml'
# Mengganti nama: 'group-rotten-cabbage-spolied-leaves-as-part-food-waste-loss-227315322_jpeg.rf.901d4275fd96219e7a9e7d66cdbe95b8.jpg' -> 'pos_0095.jpg'
# Mengganti nama: 'group-rotten-cabbage-spolied-leaves-as-part-food-waste-loss-227315322_jpeg.rf.901d4275fd96219e7a9e7d66cdbe95b8.xml' -> 'pos_0095.xml'
# Mengganti nama: 'h5ax0p-1-_jpeg.rf.1a160b431ab9e7cec684feb594208dd1.jpg' -> 'pos_0096.jpg'
# Mengganti nama: 'h5ax0p-1-_jpeg.rf.1a160b431ab9e7cec684feb594208dd1.xml' -> 'pos_0096.xml'
# Mengganti nama: 'h5ax0p-1-_jpeg.rf.7745ea1353d7cde120f8098a8e84b6e7.jpg' -> 'pos_0097.jpg'
# Mengganti nama: 'h5ax0p-1-_jpeg.rf.7745ea1353d7cde120f8098a8e84b6e7.xml' -> 'pos_0097.xml'
# Mengganti nama: 'half-of-rotten-cabbage-isolated-on-white-background-KM49FP_jpeg.rf.764b6aeaa875cf6a93dc52d915038555.jpg' -> 'pos_0098.jpg'
# Mengganti nama: 'half-of-rotten-cabbage-isolated-on-white-background-KM49FP_jpeg.rf.764b6aeaa875cf6a93dc52d915038555.xml' -> 'pos_0098.xml'
# Mengganti nama: 'half-of-rotten-cabbage-isolated-on-white-background-KM49FP_jpeg.rf.d805490f8e1fc6e0e8f35bb9f82fdef2.jpg' -> 'pos_0099.jpg'
# Mengganti nama: 'half-of-rotten-cabbage-isolated-on-white-background-KM49FP_jpeg.rf.d805490f8e1fc6e0e8f35bb9f82fdef2.xml' -> 'pos_0099.xml'
# Mengganti nama: 'half-of-rotten-cabbage-isolated-on-white-background-KM49FP_jpeg.rf.e87e8925d57c9b3f230079713162ed2d.jpg' -> 'pos_0100.jpg'
# Mengganti nama: 'half-of-rotten-cabbage-isolated-on-white-background-KM49FP_jpeg.rf.e87e8925d57c9b3f230079713162ed2d.xml' -> 'pos_0100.xml'
# Mengganti nama: 'image-450w-419371675_jpeg.rf.09f7c3b9ba1d4f8ff6bb5ab84f4e1894.jpg' -> 'pos_0101.jpg'
# Mengganti nama: 'image-450w-419371675_jpeg.rf.09f7c3b9ba1d4f8ff6bb5ab84f4e1894.xml' -> 'pos_0101.xml'
# Mengganti nama: 'image-450w-419371675_jpeg.rf.9ef2ba7870a35736224228a4e3f323bb.jpg' -> 'pos_0102.jpg'
# Mengganti nama: 'image-450w-419371675_jpeg.rf.9ef2ba7870a35736224228a4e3f323bb.xml' -> 'pos_0102.xml'
# Mengganti nama: 'image-450w-419371675_jpeg.rf.d77e048e5a4c6b16bc232c937ed9f733.jpg' -> 'pos_0103.jpg'
# Mengganti nama: 'image-450w-419371675_jpeg.rf.d77e048e5a4c6b16bc232c937ed9f733.xml' -> 'pos_0103.xml'
#
# Proses penamaan ulang selesai. Total 103 pasangan file (JPG dan XML) berhasil diganti namanya.

# %%
import os
import glob

def rename_negative_files(directory, prefix="neg_"):
    """
    Mengganti nama file gambar di direktori tertentu menjadi format berurutan
    (misal: neg_0001.jpg, neg_0002.jpg).

    Args:
        directory (str): Path ke direktori yang berisi gambar negatif.
        prefix (str): Awalan untuk nama file baru (default: "neg_").
    """
    print(f"Memulai proses penamaan ulang di direktori: {directory}")

    # Mengumpulkan semua file gambar
    # Gunakan glob untuk menemukan semua file dengan ekstensi .jpg, .jpeg, .png, .bmp
    image_files = []
    for ext in ['*.jpg', '*.jpeg', '*.png', '*.bmp']:
        image_files.extend(glob.glob(os.path.join(directory, ext)))

    image_files.sort() # Urutkan file agar penamaan berurutan konsisten

    if not image_files:
        print("Tidak ada file gambar yang ditemukan di direktori ini.")
        return

    print(f"Ditemukan {len(image_files)} file gambar untuk diproses.")

    renamed_count = 0
    for i, old_image_path in enumerate(image_files):
        # Pisahkan nama file dan ekstensi
        image_extension = os.path.splitext(old_image_path)[1]

        # Buat nama baru yang berurutan
        new_base_name = f"{prefix}{i+1:04d}" # Menggunakan 4 digit padding (0001, 0002, ...)
        new_image_path = os.path.join(directory, new_base_name + image_extension)

        try:
            # Ganti nama file gambar
            os.rename(old_image_path, new_image_path)
            print(f"Mengganti nama: '{os.path.basename(old_image_path)}' -> '{os.path.basename(new_image_path)}'")
            renamed_count += 1
        except OSError as e:
            print(f"Error saat mengganti nama '{old_image_path}': {e}")

    print(f"\nProses penamaan ulang selesai. Total {renamed_count} file gambar berhasil diganti namanya.")

# --- Cara Penggunaan ---
if __name__ == "__main__":
    # GANTI DENGAN PATH KE FOLDER "Gambar Negatif" ANDA
    negative_images_folder = r"D:\Penelitian Skripsi\Dataset\Gambar Negatif"

    rename_negative_files(negative_images_folder)
# Out:
# Memulai proses penamaan ulang di direktori: D:\Penelitian Skripsi\Dataset\Gambar Negatif
# Ditemukan 300 file gambar untuk diproses.
# Mengganti nama: '0001.jpg' -> 'neg_0001.jpg'
# Mengganti nama: '0002.jpg' -> 'neg_0002.jpg'
# Mengganti nama: '0003.jpg' -> 'neg_0003.jpg'
# Mengganti nama: '0004.jpg' -> 'neg_0004.jpg'
# Mengganti nama: '0005.jpg' -> 'neg_0005.jpg'
# Mengganti nama: '0006.jpg' -> 'neg_0006.jpg'
# Mengganti nama: '0007.jpg' -> 'neg_0007.jpg'
# Mengganti nama: '0008.jpg' -> 'neg_0008.jpg'
# Mengganti nama: '0009.jpg' -> 'neg_0009.jpg'
# Mengganti nama: '0010.jpg' -> 'neg_0010.jpg'
# Mengganti nama: '0011.jpg' -> 'neg_0011.jpg'
# Mengganti nama: '0012.jpg' -> 'neg_0012.jpg'
# Mengganti nama: '0013.jpg' -> 'neg_0013.jpg'
# Mengganti nama: '0014.jpg' -> 'neg_0014.jpg'
# Mengganti nama: '0015.jpg' -> 'neg_0015.jpg'
# Mengganti nama: '0016.jpg' -> 'neg_0016.jpg'
# Mengganti nama: '0017.jpg' -> 'neg_0017.jpg'
# Mengganti nama: '0018.jpg' -> 'neg_0018.jpg'
# Mengganti nama: '0019.jpg' -> 'neg_0019.jpg'
# Mengganti nama: '0020.jpg' -> 'neg_0020.jpg'
# Mengganti nama: '0021.jpg' -> 'neg_0021.jpg'
# Mengganti nama: '0022.jpg' -> 'neg_0022.jpg'
# Mengganti nama: '0100.jpg' -> 'neg_0023.jpg'
# Mengganti nama: '0101.jpg' -> 'neg_0024.jpg'
# Mengganti nama: '0102.jpg' -> 'neg_0025.jpg'
# Mengganti nama: '1001.jpg' -> 'neg_0026.jpg'
# Mengganti nama: '1002.jpg' -> 'neg_0027.jpg'
# Mengganti nama: '1003.jpg' -> 'neg_0028.jpg'
# Mengganti nama: '1004.jpg' -> 'neg_0029.jpg'
# Mengganti nama: '1005.jpg' -> 'neg_0030.jpg'
# Mengganti nama: '1006.jpg' -> 'neg_0031.jpg'
# Mengganti nama: '1007.jpg' -> 'neg_0032.jpg'
# Mengganti nama: '1008.jpg' -> 'neg_0033.jpg'
# Mengganti nama: '1009.jpg' -> 'neg_0034.jpg'
# Mengganti nama: '1010.jpg' -> 'neg_0035.jpg'
# Mengganti nama: '1011.jpg' -> 'neg_0036.jpg'
# Mengganti nama: '1012.jpg' -> 'neg_0037.jpg'
# Mengganti nama: '1013.jpg' -> 'neg_0038.jpg'
# Mengganti nama: '1014.jpg' -> 'neg_0039.jpg'
# Mengganti nama: '1015.jpg' -> 'neg_0040.jpg'
# Mengganti nama: '1016.jpg' -> 'neg_0041.jpg'
# Mengganti nama: '1017.jpg' -> 'neg_0042.jpg'
# Mengganti nama: '1018.jpg' -> 'neg_0043.jpg'
# Mengganti nama: '1019.jpg' -> 'neg_0044.jpg'
# Mengganti nama: '1020.jpg' -> 'neg_0045.jpg'
# Mengganti nama: '1021.jpg' -> 'neg_0046.jpg'
# Mengganti nama: '1022.jpg' -> 'neg_0047.jpg'
# Mengganti nama: '1023.jpg' -> 'neg_0048.jpg'
# Mengganti nama: '1024.jpg' -> 'neg_0049.jpg'
# Mengganti nama: '1025.jpg' -> 'neg_0050.jpg'
# Mengganti nama: '1026.jpg' -> 'neg_0051.jpg'
# Mengganti nama: '1027.jpg' -> 'neg_0052.jpg'
# Mengganti nama: '1028.jpg' -> 'neg_0053.jpg'
# Mengganti nama: '1071.jpg' -> 'neg_0054.jpg'
# Mengganti nama: '1072.jpg' -> 'neg_0055.jpg'
# Mengganti nama: '1073.jpg' -> 'neg_0056.jpg'
# Mengganti nama: '1074.jpg' -> 'neg_0057.jpg'
# Mengganti nama: '1075.jpg' -> 'neg_0058.jpg'
# Mengganti nama: '1076.jpg' -> 'neg_0059.jpg'
# Mengganti nama: '1077.jpg' -> 'neg_0060.jpg'
# Mengganti nama: '1078.jpg' -> 'neg_0061.jpg'
# Mengganti nama: '1079.jpg' -> 'neg_0062.jpg'
# Mengganti nama: '1080.jpg' -> 'neg_0063.jpg'
# Mengganti nama: '1081.jpg' -> 'neg_0064.jpg'
# Mengganti nama: '1082.jpg' -> 'neg_0065.jpg'
# Mengganti nama: '1083.jpg' -> 'neg_0066.jpg'
# Mengganti nama: '1084.jpg' -> 'neg_0067.jpg'
# Mengganti nama: '1085.jpg' -> 'neg_0068.jpg'
# Mengganti nama: '1086.jpg' -> 'neg_0069.jpg'
# Mengganti nama: '1087.jpg' -> 'neg_0070.jpg'
# Mengganti nama: '1088.jpg' -> 'neg_0071.jpg'
# Mengganti nama: '1089.jpg' -> 'neg_0072.jpg'
# Mengganti nama: '1090.jpg' -> 'neg_0073.jpg'
# Mengganti nama: '1091.jpg' -> 'neg_0074.jpg'
# Mengganti nama: '1092.jpg' -> 'neg_0075.jpg'
# Mengganti nama: '1093.jpg' -> 'neg_0076.jpg'
# Mengganti nama: '1094.jpg' -> 'neg_0077.jpg'
# Mengganti nama: '1095.jpg' -> 'neg_0078.jpg'
# Mengganti nama: '1096.jpg' -> 'neg_0079.jpg'
# Mengganti nama: '1097.jpg' -> 'neg_0080.jpg'
# Mengganti nama: '1098.jpg' -> 'neg_0081.jpg'
# Mengganti nama: '1099.jpg' -> 'neg_0082.jpg'
# Mengganti nama: '1100.jpg' -> 'neg_0083.jpg'
# Mengganti nama: '1101.jpg' -> 'neg_0084.jpg'
# Mengganti nama: '1102.jpg' -> 'neg_0085.jpg'
# Mengganti nama: '1103.jpg' -> 'neg_0086.jpg'
# Mengganti nama: '1104.jpg' -> 'neg_0087.jpg'
# Mengganti nama: '1105.jpg' -> 'neg_0088.jpg'
# Mengganti nama: '1106.jpg' -> 'neg_0089.jpg'
# Mengganti nama: '1107.jpg' -> 'neg_0090.jpg'
# Mengganti nama: '1153.jpg' -> 'neg_0091.jpg'
# Mengganti nama: '1154.jpg' -> 'neg_0092.jpg'
# Mengganti nama: '1155.jpg' -> 'neg_0093.jpg'
# Mengganti nama: '1156.jpg' -> 'neg_0094.jpg'
# Mengganti nama: '1167.jpg' -> 'neg_0095.jpg'
# Mengganti nama: '1168.jpg' -> 'neg_0096.jpg'
# Mengganti nama: '1169.jpg' -> 'neg_0097.jpg'
# Mengganti nama: '1170.jpg' -> 'neg_0098.jpg'
# Mengganti nama: '1171.jpg' -> 'neg_0099.jpg'
# Mengganti nama: '1172.jpg' -> 'neg_0100.jpg'
# Mengganti nama: '1173.jpg' -> 'neg_0101.jpg'
# Mengganti nama: '1174.jpg' -> 'neg_0102.jpg'
# Mengganti nama: '1175.jpg' -> 'neg_0103.jpg'
# Mengganti nama: '1176.jpg' -> 'neg_0104.jpg'
# Mengganti nama: '1177.jpg' -> 'neg_0105.jpg'
# Mengganti nama: '1178.jpg' -> 'neg_0106.jpg'
# Mengganti nama: '1179.jpg' -> 'neg_0107.jpg'
# Mengganti nama: '1180.jpg' -> 'neg_0108.jpg'
# Mengganti nama: '1181.jpg' -> 'neg_0109.jpg'
# Mengganti nama: '1182.jpg' -> 'neg_0110.jpg'
# Mengganti nama: '1183.jpg' -> 'neg_0111.jpg'
# Mengganti nama: '1184.jpg' -> 'neg_0112.jpg'
# Mengganti nama: '1185.jpg' -> 'neg_0113.jpg'
# Mengganti nama: '1186.jpg' -> 'neg_0114.jpg'
# Mengganti nama: '1187.jpg' -> 'neg_0115.jpg'
# Mengganti nama: '1188.jpg' -> 'neg_0116.jpg'
# Mengganti nama: '1189.jpg' -> 'neg_0117.jpg'
# Mengganti nama: '1190.jpg' -> 'neg_0118.jpg'
# Mengganti nama: '1191.jpg' -> 'neg_0119.jpg'
# Mengganti nama: '1192.jpg' -> 'neg_0120.jpg'
# Mengganti nama: '1193.jpg' -> 'neg_0121.jpg'
# Mengganti nama: '1194.jpg' -> 'neg_0122.jpg'
# Mengganti nama: '1195.jpg' -> 'neg_0123.jpg'
# Mengganti nama: '1196.jpg' -> 'neg_0124.jpg'
# Mengganti nama: '1197.jpg' -> 'neg_0125.jpg'
# Mengganti nama: '1198.jpg' -> 'neg_0126.jpg'
# Mengganti nama: '1199.jpg' -> 'neg_0127.jpg'
# Mengganti nama: '1200.jpg' -> 'neg_0128.jpg'
# Mengganti nama: 'BROKOLI 001.jpg' -> 'neg_0129.jpg'
# Mengganti nama: 'BROKOLI 002.jpg' -> 'neg_0130.jpg'
# Mengganti nama: 'BROKOLI 003.jpg' -> 'neg_0131.jpg'
# Mengganti nama: 'BROKOLI 004.jpg' -> 'neg_0132.jpg'
# Mengganti nama: 'BROKOLI 005.jpg' -> 'neg_0133.jpg'
# Mengganti nama: 'BROKOLI 006.jpg' -> 'neg_0134.jpg'
# Mengganti nama: 'BROKOLI 007.jpg' -> 'neg_0135.jpg'
# Mengganti nama: 'BROKOLI 008.jpg' -> 'neg_0136.jpg'
# Mengganti nama: 'BROKOLI 009.jpg' -> 'neg_0137.jpg'
# Mengganti nama: 'BROKOLI 010.jpg' -> 'neg_0138.jpg'
# Mengganti nama: 'BROKOLI 011.jpg' -> 'neg_0139.jpg'
# Mengganti nama: 'BROKOLI 012.jpg' -> 'neg_0140.jpg'
# Mengganti nama: 'BROKOLI 013.jpg' -> 'neg_0141.jpg'
# Mengganti nama: 'BROKOLI 014.jpg' -> 'neg_0142.jpg'
# Mengganti nama: 'BROKOLI 015.jpg' -> 'neg_0143.jpg'
# Mengganti nama: 'BROKOLI 016.jpg' -> 'neg_0144.jpg'
# Mengganti nama: 'BROKOLI 017.jpg' -> 'neg_0145.jpg'
# Mengganti nama: 'BROKOLI 018.jpg' -> 'neg_0146.jpg'
# Mengganti nama: 'BROKOLI 019.jpg' -> 'neg_0147.jpg'
# Mengganti nama: 'BROKOLI 020.jpg' -> 'neg_0148.jpg'
# Mengganti nama: 'BROKOLI 021.jpg' -> 'neg_0149.jpg'
# Mengganti nama: 'BROKOLI 022.jpg' -> 'neg_0150.jpg'
# Mengganti nama: 'BROKOLI 023.jpg' -> 'neg_0151.jpg'
# Mengganti nama: 'BROKOLI 024.jpg' -> 'neg_0152.jpg'
# Mengganti nama: 'BROKOLI 025.jpg' -> 'neg_0153.jpg'
# Mengganti nama: 'Black_Soil_-11-_original_rotated90_jpg.rf.a46761fac947f4dde313cae65122e0a6.jpg' -> 'neg_0154.jpg'
# Mengganti nama: 'Black_Soil_-11-_rotated_rotated90_jpg.rf.edabc96a04e4dbaadbbd1ac460cc929e.jpg' -> 'neg_0155.jpg'
# Mengganti nama: 'Black_Soil_-12-_rotated90_jpg.rf.322f3a65d11c7dae345b88a948b83904.jpg' -> 'neg_0156.jpg'
# Mengganti nama: 'Black_Soil_-19-_rotated90_jpg.rf.7896742ac55dd13576215705e6fa1e49.jpg' -> 'neg_0157.jpg'
# Mengganti nama: 'Black_Soil_-2-_original_jpg.rf.43796113e19eb46b856d0e93db86f4f1.jpg' -> 'neg_0158.jpg'
# Mengganti nama: 'Black_Soil_-2-_original_rotated90_jpg.rf.fc3a77af354e75151cdb72f6660a1302.jpg' -> 'neg_0159.jpg'
# Mengganti nama: 'Black_Soil_-21-_original_rotated90_jpg.rf.02d616998af3ab7e94f6c4b147f3d22a.jpg' -> 'neg_0160.jpg'
# Mengganti nama: 'Black_Soil_-22-_rotated_rotated180_jpg.rf.85ded2c37adc792746ab69c72b7a2c38.jpg' -> 'neg_0161.jpg'
# Mengganti nama: 'Black_Soil_-23-_original_original_jpg.rf.4650b63f059dd3c1e87525879e3fa70c.jpg' -> 'neg_0162.jpg'
# Mengganti nama: 'Black_Soil_-24-_original_rotated90_jpg.rf.9c61b6115934082618d722e44a9163c8.jpg' -> 'neg_0163.jpg'
# Mengganti nama: 'Black_Soil_-24-_rotated270_jpg.rf.b0513e83d39c080c3f2ee2be34e4aaf8.jpg' -> 'neg_0164.jpg'
# Mengganti nama: 'Black_Soil_-24-_rotated_original_jpg.rf.21f2c7bb8e5cd249bdec4f58e1597357.jpg' -> 'neg_0165.jpg'
# Mengganti nama: 'Black_Soil_-25-_rotated90_jpg.rf.b7639254862d499466944e0bc8e55e6f.jpg' -> 'neg_0166.jpg'
# Mengganti nama: 'Black_Soil_-26-_original_jpg.rf.75e74f2c92a9f5bc610e3bc4309a8d04.jpg' -> 'neg_0167.jpg'
# Mengganti nama: 'Black_Soil_-26-_original_original_jpg.rf.a136d420716515abd656ab4539703f17.jpg' -> 'neg_0168.jpg'
# Mengganti nama: 'Black_Soil_-26-_rotated270_jpg.rf.dcd7ec88d09f781c478c22d4bd0afe99.jpg' -> 'neg_0169.jpg'
# Mengganti nama: 'Black_Soil_-26-_rotated_rotated270_jpg.rf.34759a7f81d40c18ef60c67a94594db1.jpg' -> 'neg_0170.jpg'
# Mengganti nama: 'Black_Soil_-26-_rotated_rotated90_jpg.rf.0f6285f93a01a0f69551c10473e440d2.jpg' -> 'neg_0171.jpg'
# Mengganti nama: 'Black_Soil_-28-_original_rotated270_jpg.rf.a2872186ab30b3a448b6177affa8ab88.jpg' -> 'neg_0172.jpg'
# Mengganti nama: 'Black_Soil_-28-_rotated90_jpg.rf.08b4ac27b7cb1dee0100a4872d0fbc70.jpg' -> 'neg_0173.jpg'
# Mengganti nama: 'Black_Soil_-28-_rotated_rotated180_jpg.rf.f0be4b552e9fff06a7af285c0aea5648.jpg' -> 'neg_0174.jpg'
# Mengganti nama: 'Black_Soil_-28-_rotated_rotated270_jpg.rf.3032385b6cc33fb8fed66807ba6c98a4.jpg' -> 'neg_0175.jpg'
# Mengganti nama: 'Black_Soil_-28-_rotated_rotated90_jpg.rf.f22b66eeb9d4e692e99f428ccdc3e460.jpg' -> 'neg_0176.jpg'
# Mengganti nama: 'Black_Soil_-3-_rotated180_jpg.rf.91e0701cd9af08a048a1aa6bac3f7dfb.jpg' -> 'neg_0177.jpg'
# Mengganti nama: 'Black_Soil_-3-_rotated_original_jpg.rf.200de838cfdec941fb9499dfe96f3c27.jpg' -> 'neg_0178.jpg'
# Mengganti nama: 'Black_Soil_-30-_original_rotated270_jpg.rf.1c86ec3cbca3b479cfa6c621e4c98167.jpg' -> 'neg_0179.jpg'
# Mengganti nama: 'Black_Soil_-31-_original_jpg.rf.bca152da600f41e5a6e99eeeffbe698c.jpg' -> 'neg_0180.jpg'
# Mengganti nama: 'Black_Soil_-34-_original_jpg.rf.47c817ee0ee32d804630e7af62afc295.jpg' -> 'neg_0181.jpg'
# Mengganti nama: 'Black_Soil_-34-_original_rotated270_jpg.rf.6d82d111f9f40a2efa185ce16efcb717.jpg' -> 'neg_0182.jpg'
# Mengganti nama: 'Black_Soil_-35-_original_resized_jpg.rf.e0f235e6f93d1424385bd094189cddab.jpg' -> 'neg_0183.jpg'
# Mengganti nama: 'Black_Soil_-36-_original_jpg.rf.302ae13409ef9bd47f5384581e14e6c4.jpg' -> 'neg_0184.jpg'
# Mengganti nama: 'Black_Soil_-36-_resized_rotated180_jpg.rf.d1accc4b873c9657b18953333a2b1eed.jpg' -> 'neg_0185.jpg'
# Mengganti nama: 'Black_Soil_-37-_original_rotated270_jpg.rf.ee9143bb77ec0cbacf89c429dabe2aa4.jpg' -> 'neg_0186.jpg'
# Mengganti nama: 'Black_Soil_-38-_original_rotated270_jpg.rf.7053aa53b4fab8104397b364f24484ed.jpg' -> 'neg_0187.jpg'
# Mengganti nama: 'Black_Soil_-38-_rotated_rotated270_jpg.rf.ec82a5099d276e20b81243ba4d22dda6.jpg' -> 'neg_0188.jpg'
# Mengganti nama: 'Black_Soil_-39-_resized_jpg.rf.08b49671c4a13bd8ed2b1168707755ef.jpg' -> 'neg_0189.jpg'
# Mengganti nama: 'Black_Soil_-40-_resized_original_jpg.rf.dd102b53e225b8ef6f957f8e7b191a41.jpg' -> 'neg_0190.jpg'
# Mengganti nama: 'Black_Soil_-40-_resized_rotated180_jpg.rf.56be973c6b164b16a58fd45e75e58415.jpg' -> 'neg_0191.jpg'
# Mengganti nama: 'Black_Soil_-42-_resized_rotated90_jpg.rf.9269dfeb3cc7ada8e9119ad3759e44d2.jpg' -> 'neg_0192.jpg'
# Mengganti nama: 'Black_Soil_-43-_rotated_rotated90_jpg.rf.d9e00d9b6f28badfd479eb67a95d039d.jpg' -> 'neg_0193.jpg'
# Mengganti nama: 'Black_Soil_-44-_original_original_jpg.rf.ae995c20f1cb9a67e5e9419998a28520.jpg' -> 'neg_0194.jpg'
# Mengganti nama: 'Black_Soil_-44-_original_rotated270_jpg.rf.f3b2f6b607ea3c53f87c67a928a8edfe.jpg' -> 'neg_0195.jpg'
# Mengganti nama: 'Black_Soil_-5-_rotated270_jpg.rf.74dfe5939426398dc08ef0b2a1a4d7b5.jpg' -> 'neg_0196.jpg'
# Mengganti nama: 'Black_Soil_-5-_rotated_rotated90_jpg.rf.a7b9c81448ed9447066a88234414ee77.jpg' -> 'neg_0197.jpg'
# Mengganti nama: 'Black_Soil_-6-_rotated_original_jpg.rf.dacd3ab559e7863a6ac371042ca9a292.jpg' -> 'neg_0198.jpg'
# Mengganti nama: 'Black_Soil_-6-_rotated_rotated270_jpg.rf.71ab44836b5ce13095fddb94a048ecfd.jpg' -> 'neg_0199.jpg'
# Mengganti nama: 'Black_Soil_-7-_original_jpg.rf.3882279f09e3691e3f420fcaebd91141.jpg' -> 'neg_0200.jpg'
# Mengganti nama: 'Black_Soil_-8-_original_jpg.rf.c66b5817361f21a155c298f86c6d4172.jpg' -> 'neg_0201.jpg'
# Mengganti nama: 'Black_Soil_-8-_original_rotated180_jpg.rf.7ee834b63c7b157f6cd349a4652d80ff.jpg' -> 'neg_0202.jpg'
# Mengganti nama: 'Black_Soil_-9-_original_rotated270_jpg.rf.9efedbe7e9dfac1357d1c7d0ceb43315.jpg' -> 'neg_0203.jpg'
# Mengganti nama: 'KEMBANG KOL 001.jpg' -> 'neg_0204.jpg'
# Mengganti nama: 'KEMBANG KOL 002.jpg' -> 'neg_0205.jpg'
# Mengganti nama: 'KEMBANG KOL 003.jpg' -> 'neg_0206.jpg'
# Mengganti nama: 'KEMBANG KOL 004.jpg' -> 'neg_0207.jpg'
# Mengganti nama: 'KEMBANG KOL 005.jpg' -> 'neg_0208.jpg'
# Mengganti nama: 'KEMBANG KOL 006.jpg' -> 'neg_0209.jpg'
# Mengganti nama: 'KEMBANG KOL 007.jpg' -> 'neg_0210.jpg'
# Mengganti nama: 'KEMBANG KOL 008.jpg' -> 'neg_0211.jpg'
# Mengganti nama: 'KEMBANG KOL 009.jpg' -> 'neg_0212.jpg'
# Mengganti nama: 'KEMBANG KOL 010.jpg' -> 'neg_0213.jpg'
# Mengganti nama: 'KEMBANG KOL 011.jpg' -> 'neg_0214.jpg'
# Mengganti nama: 'KEMBANG KOL 012.jpg' -> 'neg_0215.jpg'
# Mengganti nama: 'KEMBANG KOL 013.jpg' -> 'neg_0216.jpg'
# Mengganti nama: 'KEMBANG KOL 014.jpg' -> 'neg_0217.jpg'
# Mengganti nama: 'KEMBANG KOL 015.jpg' -> 'neg_0218.jpg'
# Mengganti nama: 'KEMBANG KOL 016.jpg' -> 'neg_0219.jpg'
# Mengganti nama: 'KEMBANG KOL 017.jpg' -> 'neg_0220.jpg'
# Mengganti nama: 'KEMBANG KOL 018.jpg' -> 'neg_0221.jpg'
# Mengganti nama: 'KEMBANG KOL 019.jpg' -> 'neg_0222.jpg'
# Mengganti nama: 'KEMBANG KOL 020.jpg' -> 'neg_0223.jpg'
# Mengganti nama: 'KEMBANG KOL 021.jpg' -> 'neg_0224.jpg'
# Mengganti nama: 'KEMBANG KOL 022.jpg' -> 'neg_0225.jpg'
# Mengganti nama: 'KEMBANG KOL 023.jpg' -> 'neg_0226.jpg'
# Mengganti nama: 'KEMBANG KOL 024.jpg' -> 'neg_0227.jpg'
# Mengganti nama: 'KEMBANG KOL 025.jpg' -> 'neg_0228.jpg'
# Mengganti nama: 'Laterite_Soil_-10-_resized_jpg.rf.0e0c3f93036853a69d1f42aa902ecaae.jpg' -> 'neg_0229.jpg'
# Mengganti nama: 'Laterite_Soil_-13-_rotated270_jpg.rf.818f26b676c997c56fd310c0e2cdfeed.jpg' -> 'neg_0230.jpg'
# Mengganti nama: 'Laterite_Soil_-14-_original_jpg.rf.4435a1b35390a2e4c4cacd3cfa9e65a1.jpg' -> 'neg_0231.jpg'
# Mengganti nama: 'Laterite_Soil_-19-_rotated270_jpg.rf.bce74996240ea417655e9ccbe5e3343d.jpg' -> 'neg_0232.jpg'
# Mengganti nama: 'Laterite_Soil_-20-_rotated180_jpg.rf.3c778e35a46f5bd07a3e1a2c6c81fe56.jpg' -> 'neg_0233.jpg'
# Mengganti nama: 'Laterite_Soil_-20-_rotated270_jpg.rf.95dbc1455e9f395742d7bf114dffc180.jpg' -> 'neg_0234.jpg'
# Mengganti nama: 'Laterite_Soil_-20-_rotated90_jpg.rf.7f9bff559f4240b07215d28fbfc82380.jpg' -> 'neg_0235.jpg'
# Mengganti nama: 'Laterite_Soil_-21-_rotated180_jpg.rf.469606de3fb179a836f1960c97cce3a9.jpg' -> 'neg_0236.jpg'
# Mengganti nama: 'Laterite_Soil_-24-_rotated270_jpg.rf.1e3bac91ec6e37fb3e467c7a29722a05.jpg' -> 'neg_0237.jpg'
# Mengganti nama: 'Laterite_Soil_-28-_original_jpg.rf.b4edaa1cc49ae9f539389f6fa2d50067.jpg' -> 'neg_0238.jpg'
# Mengganti nama: 'Laterite_Soil_-3-_resized_jpg.rf.ed99759bcba0d14fcdad5f8f532d9a93.jpg' -> 'neg_0239.jpg'
# Mengganti nama: 'Laterite_Soil_-36-_original_jpg.rf.3e96953f2946479b60306b1354ce1dd2.jpg' -> 'neg_0240.jpg'
# Mengganti nama: 'Laterite_Soil_-4-_original_jpg.rf.159b1376ad543aade5d0c6cb03dfe4c4.jpg' -> 'neg_0241.jpg'
# Mengganti nama: 'Laterite_Soil_-40-_original_jpg.rf.245bc49d2a1c901d0a3f472b45ac21ec.jpg' -> 'neg_0242.jpg'
# Mengganti nama: 'Laterite_Soil_-47-_rotated180_jpg.rf.e25d390c5005c533a909c7a06b0dfe94.jpg' -> 'neg_0243.jpg'
# Mengganti nama: 'Laterite_Soil_-52-_rotated180_jpg.rf.94a696dea7f1da45383159e5bd99a763.jpg' -> 'neg_0244.jpg'
# Mengganti nama: 'Laterite_Soil_-55-_rotated180_jpg.rf.821e8d456fafa5d506e1ea420a99ce44.jpg' -> 'neg_0245.jpg'
# Mengganti nama: 'Laterite_Soil_-55-_rotated270_jpg.rf.bea1233451cd1a6f54684e8b691dddcc.jpg' -> 'neg_0246.jpg'
# Mengganti nama: 'Laterite_Soil_-58-_original_jpg.rf.6bffd0226596be58eda33d399f3280b9.jpg' -> 'neg_0247.jpg'
# Mengganti nama: 'Laterite_Soil_-6-_resized_jpg.rf.827e9d5202e4a9d00d0c5a7b95caf286.jpg' -> 'neg_0248.jpg'
# Mengganti nama: 'Laterite_Soil_-7-_rotated270_jpg.rf.700debfb378ce425cf25e721d95a9068.jpg' -> 'neg_0249.jpg'
# Mengganti nama: 'Laterite_Soil_-9-_rotated270_jpg.rf.b812ee1337a89c26f495e2269d24f030.jpg' -> 'neg_0250.jpg'
# Mengganti nama: 'TIMUN 001.jpg' -> 'neg_0251.jpg'
# Mengganti nama: 'TIMUN 002.jpg' -> 'neg_0252.jpg'
# Mengganti nama: 'TIMUN 003.jpg' -> 'neg_0253.jpg'
# Mengganti nama: 'TIMUN 004.jpg' -> 'neg_0254.jpg'
# Mengganti nama: 'TIMUN 005.jpg' -> 'neg_0255.jpg'
# Mengganti nama: 'TIMUN 006.jpg' -> 'neg_0256.jpg'
# Mengganti nama: 'TIMUN 007.jpg' -> 'neg_0257.jpg'
# Mengganti nama: 'TIMUN 008.jpg' -> 'neg_0258.jpg'
# Mengganti nama: 'TIMUN 009.jpg' -> 'neg_0259.jpg'
# Mengganti nama: 'TIMUN 010.jpg' -> 'neg_0260.jpg'
# Mengganti nama: 'TIMUN 011.jpg' -> 'neg_0261.jpg'
# Mengganti nama: 'TIMUN 012.jpg' -> 'neg_0262.jpg'
# Mengganti nama: 'TIMUN 013.jpg' -> 'neg_0263.jpg'
# Mengganti nama: 'TIMUN 014.jpg' -> 'neg_0264.jpg'
# Mengganti nama: 'TIMUN 015.jpg' -> 'neg_0265.jpg'
# Mengganti nama: 'TIMUN 016.jpg' -> 'neg_0266.jpg'
# Mengganti nama: 'TIMUN 017.jpg' -> 'neg_0267.jpg'
# Mengganti nama: 'TIMUN 018.jpg' -> 'neg_0268.jpg'
# Mengganti nama: 'TIMUN 019.jpg' -> 'neg_0269.jpg'
# Mengganti nama: 'TIMUN 020.jpg' -> 'neg_0270.jpg'
# Mengganti nama: 'TIMUN 021.jpg' -> 'neg_0271.jpg'
# Mengganti nama: 'TIMUN 022.jpg' -> 'neg_0272.jpg'
# Mengganti nama: 'TIMUN 023.jpg' -> 'neg_0273.jpg'
# Mengganti nama: 'TIMUN 024.jpg' -> 'neg_0274.jpg'
# Mengganti nama: 'TIMUN 025.jpg' -> 'neg_0275.jpg'
# Mengganti nama: 'Tomat 001.jpg' -> 'neg_0276.jpg'
# Mengganti nama: 'Tomat 002.jpg' -> 'neg_0277.jpg'
# Mengganti nama: 'Tomat 003.jpg' -> 'neg_0278.jpg'
# Mengganti nama: 'Tomat 004.jpg' -> 'neg_0279.jpg'
# Mengganti nama: 'Tomat 005.jpg' -> 'neg_0280.jpg'
# Mengganti nama: 'Tomat 006.jpg' -> 'neg_0281.jpg'
# Mengganti nama: 'Tomat 007.jpg' -> 'neg_0282.jpg'
# Mengganti nama: 'Tomat 008.jpg' -> 'neg_0283.jpg'
# Mengganti nama: 'Tomat 009.jpg' -> 'neg_0284.jpg'
# Mengganti nama: 'Tomat 010.jpg' -> 'neg_0285.jpg'
# Mengganti nama: 'Tomat 011.jpg' -> 'neg_0286.jpg'
# Mengganti nama: 'Tomat 012.jpg' -> 'neg_0287.jpg'
# Mengganti nama: 'Tomat 013.jpg' -> 'neg_0288.jpg'
# Mengganti nama: 'Tomat 014.jpg' -> 'neg_0289.jpg'
# Mengganti nama: 'Tomat 015.jpg' -> 'neg_0290.jpg'
# Mengganti nama: 'Tomat 016.jpg' -> 'neg_0291.jpg'
# Mengganti nama: 'Tomat 017.jpg' -> 'neg_0292.jpg'
# Mengganti nama: 'Tomat 018.jpg' -> 'neg_0293.jpg'
# Mengganti nama: 'Tomat 019.jpg' -> 'neg_0294.jpg'
# Mengganti nama: 'Tomat 020.jpg' -> 'neg_0295.jpg'
# Mengganti nama: 'Tomat 021.jpg' -> 'neg_0296.jpg'
# Mengganti nama: 'Tomat 022.jpg' -> 'neg_0297.jpg'
# Mengganti nama: 'Tomat 023.jpg' -> 'neg_0298.jpg'
# Mengganti nama: 'Tomat 024.jpg' -> 'neg_0299.jpg'
# Mengganti nama: 'Tomat 025.jpg' -> 'neg_0300.jpg'
#
# Proses penamaan ulang selesai. Total 300 file gambar berhasil diganti namanya.

# %%
import os
import glob
import xml.etree.ElementTree as ET

def create_positives_txt(positive_images_dir, output_file_path):
    """
    Membuat file 'positives.txt' dari gambar dan file XML anotasi.
    Format output: path/ke/gambar.jpg <jumlah_objek> <x> <y> <lebar> <tinggi> ...
    """
    print(f"Membuat 'positives.txt' dari direktori: {positive_images_dir}")
    count_objects = 0
    with open(output_file_path, 'w') as f:
        # Cari semua file gambar yang mungkin ada di direktori positif
        image_files = []
        for ext in ['*.jpg', '*.jpeg', '*.png', '*.bmp']:
            image_files.extend(glob.glob(os.path.join(positive_images_dir, ext)))
        image_files.sort() # Urutkan agar output TXT juga terurut

        for image_path in image_files:
            # Dapatkan nama dasar file tanpa ekstensi
            base_name = os.path.splitext(os.path.basename(image_path))[0]
            xml_path = os.path.join(positive_images_dir, base_name + '.xml')

            if os.path.exists(xml_path):
                try:
                    tree = ET.parse(xml_path)
                    root = tree.getroot()

                    objects_info = []
                    for obj in root.findall('object'):
                        # Asumsi format XML adalah PASCAL VOC atau serupa dengan <xmin>, <ymin>, <xmax>, <ymax>
                        bndbox = obj.find('bndbox')
                        xmin = int(bndbox.find('xmin').text)
                        ymin = int(bndbox.find('ymin').text)
                        xmax = int(bndbox.find('xmax').text)
                        ymax = int(bndbox.find('ymax').text)

                        width = xmax - xmin
                        height = ymax - ymin
                        objects_info.append(f"{xmin} {ymin} {width} {height}")
                        count_objects += 1

                    if objects_info:
                        # Tulis path relatif dan informasi objek ke file TXT
                        relative_path = os.path.relpath(image_path, start=os.path.dirname(output_file_path))
                        line = f"{relative_path} {len(objects_info)} {' '.join(objects_info)}\n"
                        f.write(line)
                    else:
                        print(f"Peringatan: Tidak ada objek yang ditemukan di XML untuk {image_path}. Melewatkan.")
                except ET.ParseError as e:
                    print(f"Error parsing XML file {xml_path}: {e}. Melewatkan.")
            else:
                print(f"Peringatan: File XML tidak ditemukan untuk {image_path}. Melewatkan.")

    print(f"Selesai membuat '{output_file_path}'. Total {count_objects} objek terdeteksi.")
    return count_objects

def create_negatives_txt(negative_images_dir, output_file_path):
    """
    Membuat file 'negatives.txt' dari daftar path gambar negatif.
    """
    print(f"Membuat 'negatives.txt' dari direktori: {negative_images_dir}")
    count_images = 0
    with open(output_file_path, 'w') as f:
        # Cari semua file gambar yang mungkin ada di direktori negatif
        image_files = []
        for ext in ['*.jpg', '*.jpeg', '*.png', '*.bmp']:
            image_files.extend(glob.glob(os.path.join(negative_images_dir, ext)))
        image_files.sort() # Urutkan agar output TXT juga terurut

        for image_path in image_files:
            # Tulis path relatif ke file TXT
            relative_path = os.path.relpath(image_path, start=os.path.dirname(output_file_path))
            f.write(f"{relative_path}\n")
            count_images += 1

    print(f"Selesai membuat '{output_file_path}'. Total {count_images} gambar negatif.")
    return count_images

if __name__ == "__main__":
    # --- KONFIGURASI PATH ANDA ---
    # Path ke folder gambar positif Anda (yang sudah dirapikan)
    positive_images_folder = r"D:\Penelitian Skripsi\Dataset\Gambar Positif"

    # Path ke folder gambar negatif Anda (yang sudah dirapikan)
    negative_images_folder = r"D:\Penelitian Skripsi\Dataset\Gambar Negatif"

    # Nama file output TXT yang akan dibuat (akan dibuat di direktori skrip ini dijalankan)
    output_positives_txt = "positives.txt"
    output_negatives_txt = "negatives.txt"

    print("--- Memulai Pembuatan File TXT untuk Haar Cascade ---")

    # Membuat positives.txt
    total_positive_objects = create_positives_txt(positive_images_folder, output_positives_txt)

    # Membuat negatives.txt
    total_negative_images = create_negatives_txt(negative_images_folder, output_negatives_txt)

    print("\n--- Proses Selesai ---")
    print(f"Jumlah total objek positif yang terdeteksi: {total_positive_objects}")
    print(f"Jumlah total gambar negatif: {total_negative_images}")
    print(f"File '{output_positives_txt}' dan '{output_negatives_txt}' telah dibuat di direktori yang sama.")
    print("Anda sekarang siap untuk melanjutkan ke langkah 'opencv_createsamples' dan 'opencv_traincascade'.")
# Out:
# --- Memulai Pembuatan File TXT untuk Haar Cascade ---
# Membuat 'positives.txt' dari direktori: D:\Penelitian Skripsi\Dataset\Gambar Positif
# Selesai membuat 'positives.txt'. Total 103 objek terdeteksi.
# Membuat 'negatives.txt' dari direktori: D:\Penelitian Skripsi\Dataset\Gambar Negatif
# Selesai membuat 'negatives.txt'. Total 300 gambar negatif.
#
# --- Proses Selesai ---
# Jumlah total objek positif yang terdeteksi: 103
# Jumlah total gambar negatif: 300
# File 'positives.txt' dan 'negatives.txt' telah dibuat di direktori yang sama.
# Anda sekarang siap untuk melanjutkan ke langkah 'opencv_createsamples' dan 'opencv_traincascade'.

# %%
!"C:\Users\acer\Downloads\opencv\build\x64\vc14\bin" -vec samples.vec -info positives.txt -num 103 -w 48 -h 48
# Out:
# '"C:\Users\acer\Downloads\opencv\build\x64\vc14\bin"' is not recognized as an internal or external command,
# operable program or batch file.

# %%
opencv_traincascade -data data/ -vec samples.vec -bg negatives.txt -numPos 90 -numNeg 270 -numStages 15 -w 48 -h 48 -featureType HAAR
